# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
data=pd.read_csv(r"C:\Users\Surendra Babu\Downloads\Summary of Weather.csv")
print(data)
# Out:
#           STA        Date Precip  WindGustSpd    MaxTemp    MinTemp  \
# 0       10001    1942-7-1  1.016          NaN  25.555556  22.222222
# 1       10001    1942-7-2      0          NaN  28.888889  21.666667
# 2       10001    1942-7-3   2.54          NaN  26.111111  22.222222
# 3       10001    1942-7-4   2.54          NaN  26.666667  22.222222
# 4       10001    1942-7-5      0          NaN  26.666667  21.666667
# ...       ...         ...    ...          ...        ...        ...
# 119035  82506  1945-12-27      0          NaN  28.333333  18.333333
# 119036  82506  1945-12-28  9.906          NaN  29.444444  18.333333
# 119037  82506  1945-12-29      0          NaN  28.333333  18.333333
# 119038  82506  1945-12-30      0          NaN  28.333333  18.333333
# 119039  82506  1945-12-31      0          NaN  29.444444  17.222222
#
#          MeanTemp Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  \
# ...

# %%
data.drop(data.iloc[:, 0:3],inplace=True,axis=1)
data
# Out:
#         WindGustSpd    MaxTemp    MinTemp   MeanTemp Snowfall PoorWeather  YR  \
# 0               NaN  25.555556  22.222222  23.888889      0.0         NaN  42
# 1               NaN  28.888889  21.666667  25.555556      0.0         NaN  42
# 2               NaN  26.111111  22.222222  24.444444      0.0         NaN  42
# 3               NaN  26.666667  22.222222  24.444444      0.0         NaN  42
# 4               NaN  26.666667  21.666667  24.444444      0.0         NaN  42
# ...             ...        ...        ...        ...      ...         ...  ..
# 119035          NaN  28.333333  18.333333  23.333333      0.0         NaN  45
# 119036          NaN  29.444444  18.333333  23.888889      0.0         1.0  45
# 119037          NaN  28.333333  18.333333  23.333333      0.0         1.0  45
# 119038          NaN  28.333333  18.333333  23.333333      0.0         NaN  45
# 119039          NaN  29.444444  17.222222  23.333333      0.0         NaN  45
#
# ...

# %%
data.corr()
# Out:
#              WindGustSpd   MaxTemp   MinTemp  MeanTemp        YR        MO  \
# WindGustSpd     1.000000 -0.124238  0.311690  0.197264       NaN  0.149525
# MaxTemp        -0.124238  1.000000  0.878384  0.969048  0.039585  0.031346
# MinTemp         0.311690  0.878384  1.000000  0.965425 -0.020733  0.069078
# MeanTemp        0.197264  0.969048  0.965425  1.000000  0.010681  0.050769
# YR                   NaN  0.039585 -0.020733  0.010681  1.000000 -0.144360
# MO              0.149525  0.031346  0.069078  0.050769 -0.144360  1.000000
# DA              0.002081 -0.005130 -0.002576 -0.004153 -0.011196  0.006563
# DR              0.351027  0.011875  0.525019  0.407395       NaN  0.655035
# SPD             1.000000 -0.124238  0.311690  0.197264       NaN  0.149525
# MAX            -0.124238  1.000000  0.872096  0.965838  0.013986  0.034329
# MIN             0.311690  0.870594  1.000000  0.963279 -0.043323  0.072453
# ...
