# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
data=pd.read_csv(r"C:\Users\Surendra Babu\Downloads\weatherHistory.csv")
print(data)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
data.corr()
# Out:
#                           Temperature (C)  Apparent Temperature (C)  Humidity  \
# Temperature (C)                  1.000000                  0.992629 -0.632255
# Apparent Temperature (C)         0.992629                  1.000000 -0.602571
# Humidity                        -0.632255                 -0.602571  1.000000
# Wind Speed (km/h)                0.008957                 -0.056650 -0.224951
# Wind Bearing (degrees)           0.029988                  0.029031  0.000735
# Visibility (km)                  0.392847                  0.381718 -0.369173
# Loud Cover                            NaN                       NaN       NaN
# Pressure (millibars)            -0.005447                 -0.000219  0.005454
#
#                           Wind Speed (km/h)  Wind Bearing (degrees)  \
# Temperature (C)                    0.008957                0.029988
# Apparent Temperature (C)          -0.056650                0.029031
# ...

# %%
data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
data=data.drop(['Formatted Date','Loud Cover','Daily Summary'],axis=1)
data
# Out:
#              Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0      Partly Cloudy        rain         9.472222                  7.388889
# 1      Partly Cloudy        rain         9.355556                  7.227778
# 2      Mostly Cloudy        rain         9.377778                  9.377778
# 3      Partly Cloudy        rain         8.288889                  5.944444
# 4      Mostly Cloudy        rain         8.755556                  6.977778
# ...              ...         ...              ...                       ...
# 96448  Partly Cloudy        rain        26.016667                 26.016667
# 96449  Partly Cloudy        rain        24.583333                 24.583333
# 96450  Partly Cloudy        rain        22.038889                 22.038889
# 96451  Partly Cloudy        rain        21.522222                 21.522222
# 96452  Partly Cloudy        rain        20.438889                 20.438889
#
# ...

# %%
from sklearn import preprocessing
l=preprocessing.LabelEncoder()
data['Summary']=l.fit_transform(data['Summary'])
data['Summary'].unique()
# Out:
# array([19, 17, 18, 12,  3,  6,  5,  4, 13, 15, 23, 25,  2, 26,  0, 11, 24,
#         7,  9, 21, 14, 16,  8, 22, 10,  1, 20])

# %%
data
# Out:
#        Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0           19        rain         9.472222                  7.388889
# 1           19        rain         9.355556                  7.227778
# 2           17        rain         9.377778                  9.377778
# 3           19        rain         8.288889                  5.944444
# 4           17        rain         8.755556                  6.977778
# ...        ...         ...              ...                       ...
# 96448       19        rain        26.016667                 26.016667
# 96449       19        rain        24.583333                 24.583333
# 96450       19        rain        22.038889                 22.038889
# 96451       19        rain        21.522222                 21.522222
# 96452       19        rain        20.438889                 20.438889
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# ...

# %%
data.isnull().sum()
# Out:
# Summary                       0
# Precip Type                 517
# Temperature (C)               0
# Apparent Temperature (C)      0
# Humidity                      0
# Wind Speed (km/h)             0
# Wind Bearing (degrees)        0
# Visibility (km)               0
# Pressure (millibars)          0
# dtype: int64

# %%
data['Wind Speed (km/h)'].fillna(value=data['Wind Speed (km/h)'].mean(),inplace=True)
data
# Out:
#        Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0           19        rain         9.472222                  7.388889
# 1           19        rain         9.355556                  7.227778
# 2           17        rain         9.377778                  9.377778
# 3           19        rain         8.288889                  5.944444
# 4           17        rain         8.755556                  6.977778
# ...        ...         ...              ...                       ...
# 96448       19        rain        26.016667                 26.016667
# 96449       19        rain        24.583333                 24.583333
# 96450       19        rain        22.038889                 22.038889
# 96451       19        rain        21.522222                 21.522222
# 96452       19        rain        20.438889                 20.438889
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# ...

# %%
data['Wind Bearing (degrees)'].fillna(value=data['Wind Bearing (degrees)'].mean(),inplace=True)
data
# Out:
#        Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0           19        rain         9.472222                  7.388889
# 1           19        rain         9.355556                  7.227778
# 2           17        rain         9.377778                  9.377778
# 3           19        rain         8.288889                  5.944444
# 4           17        rain         8.755556                  6.977778
# ...        ...         ...              ...                       ...
# 96448       19        rain        26.016667                 26.016667
# 96449       19        rain        24.583333                 24.583333
# 96450       19        rain        22.038889                 22.038889
# 96451       19        rain        21.522222                 21.522222
# 96452       19        rain        20.438889                 20.438889
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# ...

# %%
data['Apparent Temperature (C)'].corr(data['Humidity'])
# Out:
# -0.60257099557339

# %%
data['Temperature (C)'].corr(data['Humidity'])
# Out:
# -0.6322546750278027

# %%
data['Temperature (C)'].corr(data['Apparent Temperature (C)'])
# Out:
# 0.9926285641921309

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Summary                   96453 non-null  int32
#  1   Precip Type               95936 non-null  object
#  2   Temperature (C)           96453 non-null  float64
#  3   Apparent Temperature (C)  96453 non-null  float64
#  4   Humidity                  96453 non-null  float64
#  5   Wind Speed (km/h)         96453 non-null  float64
#  6   Wind Bearing (degrees)    96453 non-null  float64
#  7   Visibility (km)           96453 non-null  float64
#  8   Pressure (millibars)      96453 non-null  float64
# dtypes: float64(7), int32(1), object(1)
# memory usage: 6.3+ MB

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ct=ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [0])], remainder='passthrough')

# %%
data
# Out:
#        Summary Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0           19        rain         9.472222                  7.388889
# 1           19        rain         9.355556                  7.227778
# 2           17        rain         9.377778                  9.377778
# 3           19        rain         8.288889                  5.944444
# 4           17        rain         8.755556                  6.977778
# ...        ...         ...              ...                       ...
# 96448       19        rain        26.016667                 26.016667
# 96449       19        rain        24.583333                 24.583333
# 96450       19        rain        22.038889                 22.038889
# 96451       19        rain        21.522222                 21.522222
# 96452       19        rain        20.438889                 20.438889
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# ...

# %%
data['Summary'].unique()
# Out:
# array([19, 17, 18, 12,  3,  6,  5,  4, 13, 15, 23, 25,  2, 26,  0, 11, 24,
#         7,  9, 21, 14, 16,  8, 22, 10,  1, 20])

# %%
data['Precip Type']=l.fit_transform(data['Precip Type'])
data['Precip Type'].unique()
# Out:
# array([0, 1, 2])

# %%
data
# Out:
#        Summary  Precip Type  Temperature (C)  Apparent Temperature (C)  \
# 0           19            0         9.472222                  7.388889
# 1           19            0         9.355556                  7.227778
# 2           17            0         9.377778                  9.377778
# 3           19            0         8.288889                  5.944444
# 4           17            0         8.755556                  6.977778
# ...        ...          ...              ...                       ...
# 96448       19            0        26.016667                 26.016667
# 96449       19            0        24.583333                 24.583333
# 96450       19            0        22.038889                 22.038889
# 96451       19            0        21.522222                 21.522222
# 96452       19            0        20.438889                 20.438889
#
#        Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# ...

# %%
integers = data.select_dtypes(include = ["int64","float64"]).keys()
print(integers)
# Out:
# Index(['Temperature (C)', 'Apparent Temperature (C)', 'Humidity',
#        'Wind Speed (km/h)', 'Wind Bearing (degrees)', 'Visibility (km)',
#        'Pressure (millibars)'],
#       dtype='object')

# %%
data[integers].describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  \
# count       96453.000000            96453.000000     96453.000000
# mean           10.810640              187.509232        10.347325
# std             6.913571              107.383428         4.192123
# min             0.000000                0.000000         0.000000
# ...

# %%
data[integers].hist()
# Out:
# array([[<AxesSubplot:title={'center':'Temperature (C)'}>,
#         <AxesSubplot:title={'center':'Apparent Temperature (C)'}>,
#         <AxesSubplot:title={'center':'Humidity'}>],
#        [<AxesSubplot:title={'center':'Wind Speed (km/h)'}>,
#         <AxesSubplot:title={'center':'Wind Bearing (degrees)'}>,
#         <AxesSubplot:title={'center':'Visibility (km)'}>],
#        [<AxesSubplot:title={'center':'Pressure (millibars)'}>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
data['Summary'].value_counts(dropna=False)
# Out:
# 19    31733
# 17    28094
# 18    16597
# 6     10890
# 12     7148
# 4       528
# 3       516
# 5       386
# 11       86
# 26       67
# 16       63
# 0        54
# 25       45
# 13       40
# 8        39
# 2        35
# 24       35
# 9        34
# 15       17
# 10       14
# 20       10
# 21        8
# 14        7
# 23        4
# 22        1
# 7         1
# 1         1
# Name: Summary, dtype: int64

# %%
X=data[['Humidity','Apparent Temperature (C)']]
y=data['Precip Type']
X
# Out:
#        Humidity  Apparent Temperature (C)
# 0          0.89                  7.388889
# 1          0.86                  7.227778
# 2          0.89                  9.377778
# 3          0.83                  5.944444
# 4          0.83                  6.977778
# ...         ...                       ...
# 96448      0.43                 26.016667
# 96449      0.48                 24.583333
# 96450      0.56                 22.038889
# 96451      0.60                 21.522222
# 96452      0.61                 20.438889
#
# [96453 rows x 2 columns]

# %%
#data normalization
X=preprocessing.StandardScaler().fit_transform(X)
X
# Out:
# array([[ 0.79347043, -0.32403547],
#        [ 0.63999555, -0.3390971 ],
#        [ 0.79347043, -0.13810226],
#        ...,
#        [-0.89475327,  1.04553403],
#        [-0.6901201 ,  0.99723295],
#        [-0.6389618 ,  0.89595648]])

# %%
X_test.shape
# Out:
# (28936, 2)

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 96448    0
# 96449    0
# 96450    0
# 96451    0
# 96452    0
# Name: Precip Type, Length: 96453, dtype: int32

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
X_train
# Out:
#        Humidity  Apparent Temperature (C)
# 16217      0.48                  6.588889
# 56608      0.53                 22.783333
# 15509      0.92                 -4.444444
# 5549       0.93                  4.527778
# 67457      0.44                 22.800000
# ...         ...                       ...
# 21243      0.90                 14.883333
# 45891      0.95                 -2.205556
# 42613      0.84                 13.577778
# 43567      0.91                 17.638889
# 68268      0.64                 13.833333
#
# [67517 rows x 2 columns]

# %%
y_train
# Out:
# 16217    0
# 56608    0
# 15509    0
# 5549     0
# 67457    0
#         ..
# 21243    0
# 45891    0
# 42613    0
# 43567    0
# 68268    0
# Name: Precip Type, Length: 67517, dtype: int32

# %%
X_train.shape
# Out:
# (67517, 2)

# %%
y_train.shape
# Out:
# (67517,)

# %%
from sklearn.neighbors import KNeighborsRegressor
model=KNeighborsRegressor()
model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
from sklearn.metrics import r2_score, mean_squared_error, recall_score
    

R2_score=r2_score(y_test,y_pred)
     

R2_score
# Out:
# 0.5854564839478913

# %%
msn=mean_squared_error(y_test,y_pred)
     

msn
# Out:
# 0.048762786839922585

# %%
rs=recall_score(y_test,y_pred,average=None)
rs
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9984\489638980.py in <module>
# ----> 1 rs=recall_score(y_test,y_pred,average=None)
#       2 rs
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in recall_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1899     array([1. , 1. , 0.5])
#    1900     """
# -> 1901     _, r, _, _ = precision_recall_fscore_support(
#    1902         y_true,
#    1903         y_pred,
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1542     if beta < 0:
#    1543         raise ValueError("beta should be >=0 in the F-beta score")
# -> 1544     labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
# ...
